# %% [markdown]
# ### Schema comparison within BRA

# %%
import pandas as pd
import chardet
from fuzzywuzzy import fuzz

# %%
with open('RAW Data/BRAantineoplasticos1.csv', 'rb') as rawdata:
    res = chardet.detect(rawdata.read(100000))
BRA_enc = res['encoding']

# %%
BRA_files=['BRAantineoplasticos1.csv', 'BRAantineoplasticos2.csv', 'BRAantineoplasticos3.csv',
          'BRACardio1.csv', 'BRACardio2.csv', 'BRACardio3.csv', 'BRAfludrocortisona.csv', 
           'BRAglibenclamida-gliclazida.csv', 'BRAinsulina.csv', 'BRAlevotiroxina.csv', 'BRAmetformina.csv']

# %%
BRA_files_fp = [f'RAW Data/{ds}' for ds in BRA_files]
BRA_files_fp
# Out:
# ['RAW Data/BRAantineoplasticos1.csv',
#  'RAW Data/BRAantineoplasticos2.csv',
#  'RAW Data/BRAantineoplasticos3.csv',
#  'RAW Data/BRACardio1.csv',
#  'RAW Data/BRACardio2.csv',
#  'RAW Data/BRACardio3.csv',
#  'RAW Data/BRAfludrocortisona.csv',
#  'RAW Data/BRAglibenclamida-gliclazida.csv',
#  'RAW Data/BRAinsulina.csv',
#  'RAW Data/BRAlevotiroxina.csv',
#  'RAW Data/BRAmetformina.csv']

# %%
columns_list = []
for BRA_file in BRA_files_fp:
    data = pd.read_csv(BRA_file, header=2, encoding=BRA_enc)
    header = list(data.columns.values)
    columns_list.append(header)
assert len(columns_list) == len(BRA_files_fp)

# %%
BRA_fp_headers = dict(zip(BRA_files_fp, columns_list))

# %%
BRA_fp_headers
# Out:
# {'RAW Data/BRAantineoplasticos1.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRAantineoplasticos2.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRAantineoplasticos3.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRACardio1.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRACardio2.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRACardio3.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRAfludrocortisona.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRAglibenclamida-gliclazida.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRAinsulina.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRAlevotiroxina.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/BRAmetformina.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0']}

# %%
# string matching function
def fuzzy_match(list1, list2):
    res = []
    for v1 in list1:
        sim = 0
        pair = {}
        for v2 in list2:
            ratio = fuzz.ratio(v1.lower(), v2.lower())
            if ratio>sim:
                sim = ratio
                pair[v1] = v2
        print(f'pair {pair}, the score is {sim}')
        res.append(pair) 
    return res

# %%
Str1 = ["Apple Inc.", "Samsung", "Huawei"]
Str2 = ["apple Inc", "apple", "Sam", "huawei inc."]
res = fuzzy_match(Str1, Str2)
print(res)
# Out:
# pair {'Apple Inc.': 'apple Inc'}, the score is 95
# pair {'Samsung': 'Sam'}, the score is 60
# pair {'Huawei': 'huawei inc.'}, the score is 71
# [{'Apple Inc.': 'apple Inc'}, {'Samsung': 'Sam'}, {'Huawei': 'huawei inc.'}]

# %%
# pairwise_compare schema 
from itertools import combinations 
def column_mapping(fp_col_dict):
    res = []
    i=0
    j=1
    items = list(fp_col_dict.items())
    for (key_1, value_1), (key_2, value_2) in combinations(fp_col_dict.items(), 2):
        fn_ij = f"{key_1.split('/')[-1].split('.')[0]}-{key_2.split('/')[-1].split('.')[0]}"
        pair_res = fuzzy_match(value_1, value_2)
        fn_pairs = {fn_ij: pair_res}
        res.append(fn_pairs)
#     for file_name_i, column_list_i in dict(list(fp_col_dict.items())[i:]).items():
#         fn_pairs = {}
#         for file_name_j, column_list_j in dict(list(fp_col_dict.items())[j:]).items():
#             fn_ij = f"{file_name_i.split('/')[-1].split('.')[0]}-{file_name_j.split('/')[-1].split('.')[0]}"
#             pair_res = fuzzy_match(column_list_i, column_list_j)
#             fn_pairs = {fn_ij: pair_res}
#             res.append(fn_pairs)
#         j+=1
#         i+=1
    return res

# %%
from pprint import pprint
BRA_mapping_res = column_mapping(BRA_fp_headers)
# Out:
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# ...
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100

# %%
pprint(BRA_mapping_res)
# Out:
# [{'BRAantineoplasticos1-BRAantineoplasticos2': [{'Código BR': 'Código BR'},
#                                                 {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                         'CATMAT'},
#                                                 {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                     'Unidade '
#                                                                                     'de '
#                                                                                     'Fornecimento\xa0'},
#                                                 {'Genérico': 'Genérico'},
#                                                 {'Registro Anvisa': 'Registro '
#                                                                     'Anvisa'},
#                                                 {'\xa0Data Compra\xa0': '\xa0'
#                                                                         'Data '
#                                                                         'Compra\xa0'},
#                                                 {'Modalidade da Compra': 'Modalidade '
#                                                                          'da '
#                                                                          'Compra'},
#                                                 {'\xa0Data Inserção': '\xa0'
#                                                                       'Data '
#                                                                       'Inserção'},
#                                                 {'Tipo Compra': 'Tipo Compra'},
#                                                 {'Fabricante': 'Fabricante'},
#                                                 {'CNPJ Fabricante': 'CNPJ '
#                                                                     'Fabricante'},
#                                                 {'Fornecedor': 'Fornecedor'},
#                                                 {'CNPJ Fornecedor': 'CNPJ '
#                                                                     'Fornecedor'},
#                                                 {'Nome Instituição': 'Nome '
#                                                                      'Instituição'},
#                                                 {'CNPJ Instituição': 'CNPJ '
#                                                                      'Instituição'},
#                                                 {'Município Instituição': 'Município '
#                                                                           'Instituição'},
#                                                 {'UF': 'UF'},
#                                                 {'Qtd Itens Comprados': 'Qtd '
#                                                                         'Itens '
#                                                                         'Comprados'},
#                                                 {'Preço Unitário': 'Preço '
#                                                                    'Unitário'},
#                                                 {'CMED - Preço Regulado': 'CMED '
#                                                                           '- '
#                                                                           'Preço '
#                                                                           'Regulado'},
#                                                 {'Competência CMED': 'Competência '
#                                                                      'CMED'},
#                                                 {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                             'Média '
#                                                                             'Ponderada\xa0'}]},
#  {'BRAantineoplasticos1-BRAantineoplasticos3': [{'Código BR': 'Código BR'},
#                                                 {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                         'CATMAT'},
#                                                 {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                     'Unidade '
#                                                                                     'de '
#                                                                                     'Fornecimento\xa0'},
#                                                 {'Genérico': 'Genérico'},
#                                                 {'Registro Anvisa': 'Registro '
#                                                                     'Anvisa'},
#                                                 {'\xa0Data Compra\xa0': '\xa0'
#                                                                         'Data '
#                                                                         'Compra\xa0'},
#                                                 {'Modalidade da Compra': 'Modalidade '
#                                                                          'da '
#                                                                          'Compra'},
#                                                 {'\xa0Data Inserção': '\xa0'
#                                                                       'Data '
#                                                                       'Inserção'},
#                                                 {'Tipo Compra': 'Tipo Compra'},
#                                                 {'Fabricante': 'Fabricante'},
#                                                 {'CNPJ Fabricante': 'CNPJ '
#                                                                     'Fabricante'},
#                                                 {'Fornecedor': 'Fornecedor'},
#                                                 {'CNPJ Fornecedor': 'CNPJ '
#                                                                     'Fornecedor'},
#                                                 {'Nome Instituição': 'Nome '
#                                                                      'Instituição'},
#                                                 {'CNPJ Instituição': 'CNPJ '
#                                                                      'Instituição'},
#                                                 {'Município Instituição': 'Município '
#                                                                           'Instituição'},
#                                                 {'UF': 'UF'},
#                                                 {'Qtd Itens Comprados': 'Qtd '
#                                                                         'Itens '
#                                                                         'Comprados'},
#                                                 {'Preço Unitário': 'Preço '
#                                                                    'Unitário'},
#                                                 {'CMED - Preço Regulado': 'CMED '
#                                                                           '- '
#                                                                           'Preço '
#                                                                           'Regulado'},
#                                                 {'Competência CMED': 'Competência '
#                                                                      'CMED'},
#                                                 {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                             'Média '
#                                                                             'Ponderada\xa0'}]},
#  {'BRAantineoplasticos1-BRACardio1': [{'Código BR': 'Código BR'},
#                                       {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                               'CATMAT'},
#                                       {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                           'Unidade '
#                                                                           'de '
#                                                                           'Fornecimento\xa0'},
#                                       {'Genérico': 'Genérico'},
#                                       {'Registro Anvisa': 'Registro Anvisa'},
#                                       {'\xa0Data Compra\xa0': '\xa0Data '
#                                                               'Compra\xa0'},
#                                       {'Modalidade da Compra': 'Modalidade da '
#                                                                'Compra'},
#                                       {'\xa0Data Inserção': '\xa0Data '
#                                                             'Inserção'},
#                                       {'Tipo Compra': 'Tipo Compra'},
#                                       {'Fabricante': 'Fabricante'},
#                                       {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                       {'Fornecedor': 'Fornecedor'},
#                                       {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                       {'Nome Instituição': 'Nome Instituição'},
#                                       {'CNPJ Instituição': 'CNPJ Instituição'},
#                                       {'Município Instituição': 'Município '
#                                                                 'Instituição'},
#                                       {'UF': 'UF'},
#                                       {'Qtd Itens Comprados': 'Qtd Itens '
#                                                               'Comprados'},
#                                       {'Preço Unitário': 'Preço Unitário'},
#                                       {'CMED - Preço Regulado': 'CMED - Preço '
#                                                                 'Regulado'},
#                                       {'Competência CMED': 'Competência CMED'},
#                                       {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                                   'Ponderada\xa0'}]},
#  {'BRAantineoplasticos1-BRACardio2': [{'Código BR': 'Código BR'},
#                                       {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                               'CATMAT'},
#                                       {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                           'Unidade '
#                                                                           'de '
#                                                                           'Fornecimento\xa0'},
#                                       {'Genérico': 'Genérico'},
#                                       {'Registro Anvisa': 'Registro Anvisa'},
#                                       {'\xa0Data Compra\xa0': '\xa0Data '
#                                                               'Compra\xa0'},
#                                       {'Modalidade da Compra': 'Modalidade da '
#                                                                'Compra'},
#                                       {'\xa0Data Inserção': '\xa0Data '
#                                                             'Inserção'},
#                                       {'Tipo Compra': 'Tipo Compra'},
#                                       {'Fabricante': 'Fabricante'},
#                                       {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                       {'Fornecedor': 'Fornecedor'},
#                                       {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                       {'Nome Instituição': 'Nome Instituição'},
#                                       {'CNPJ Instituição': 'CNPJ Instituição'},
#                                       {'Município Instituição': 'Município '
#                                                                 'Instituição'},
#                                       {'UF': 'UF'},
#                                       {'Qtd Itens Comprados': 'Qtd Itens '
#                                                               'Comprados'},
#                                       {'Preço Unitário': 'Preço Unitário'},
#                                       {'CMED - Preço Regulado': 'CMED - Preço '
#                                                                 'Regulado'},
#                                       {'Competência CMED': 'Competência CMED'},
#                                       {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                                   'Ponderada\xa0'}]},
#  {'BRAantineoplasticos1-BRACardio3': [{'Código BR': 'Código BR'},
#                                       {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                               'CATMAT'},
#                                       {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                           'Unidade '
#                                                                           'de '
#                                                                           'Fornecimento\xa0'},
#                                       {'Genérico': 'Genérico'},
#                                       {'Registro Anvisa': 'Registro Anvisa'},
#                                       {'\xa0Data Compra\xa0': '\xa0Data '
#                                                               'Compra\xa0'},
#                                       {'Modalidade da Compra': 'Modalidade da '
#                                                                'Compra'},
#                                       {'\xa0Data Inserção': '\xa0Data '
#                                                             'Inserção'},
#                                       {'Tipo Compra': 'Tipo Compra'},
#                                       {'Fabricante': 'Fabricante'},
#                                       {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                       {'Fornecedor': 'Fornecedor'},
#                                       {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                       {'Nome Instituição': 'Nome Instituição'},
#                                       {'CNPJ Instituição': 'CNPJ Instituição'},
#                                       {'Município Instituição': 'Município '
#                                                                 'Instituição'},
#                                       {'UF': 'UF'},
#                                       {'Qtd Itens Comprados': 'Qtd Itens '
#                                                               'Comprados'},
#                                       {'Preço Unitário': 'Preço Unitário'},
#                                       {'CMED - Preço Regulado': 'CMED - Preço '
#                                                                 'Regulado'},
#                                       {'Competência CMED': 'Competência CMED'},
#                                       {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                                   'Ponderada\xa0'}]},
#  {'BRAantineoplasticos1-BRAfludrocortisona': [{'Código BR': 'Código BR'},
#                                               {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                       'CATMAT'},
#                                               {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                   'Unidade '
#                                                                                   'de '
#                                                                                   'Fornecimento\xa0'},
#                                               {'Genérico': 'Genérico'},
#                                               {'Registro Anvisa': 'Registro '
#                                                                   'Anvisa'},
#                                               {'\xa0Data Compra\xa0': '\xa0'
#                                                                       'Data '
#                                                                       'Compra\xa0'},
#                                               {'Modalidade da Compra': 'Modalidade '
#                                                                        'da '
#                                                                        'Compra'},
#                                               {'\xa0Data Inserção': '\xa0Data '
#                                                                     'Inserção'},
#                                               {'Tipo Compra': 'Tipo Compra'},
#                                               {'Fabricante': 'Fabricante'},
#                                               {'CNPJ Fabricante': 'CNPJ '
#                                                                   'Fabricante'},
#                                               {'Fornecedor': 'Fornecedor'},
#                                               {'CNPJ Fornecedor': 'CNPJ '
#                                                                   'Fornecedor'},
#                                               {'Nome Instituição': 'Nome '
#                                                                    'Instituição'},
#                                               {'CNPJ Instituição': 'CNPJ '
#                                                                    'Instituição'},
#                                               {'Município Instituição': 'Município '
#                                                                         'Instituição'},
#                                               {'UF': 'UF'},
#                                               {'Qtd Itens Comprados': 'Qtd '
#                                                                       'Itens '
#                                                                       'Comprados'},
#                                               {'Preço Unitário': 'Preço '
#                                                                  'Unitário'},
#                                               {'CMED - Preço Regulado': 'CMED '
#                                                                         '- '
#                                                                         'Preço '
#                                                                         'Regulado'},
#                                               {'Competência CMED': 'Competência '
#                                                                    'CMED'},
#                                               {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                           'Média '
#                                                                           'Ponderada\xa0'}]},
#  {'BRAantineoplasticos1-BRAglibenclamida-gliclazida': [{'Código BR': 'Código '
#                                                                      'BR'},
#                                                        {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                                'CATMAT'},
#                                                        {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                            'Unidade '
#                                                                                            'de '
#                                                                                            'Fornecimento\xa0'},
#                                                        {'Genérico': 'Genérico'},
#                                                        {'Registro Anvisa': 'Registro '
#                                                                            'Anvisa'},
#                                                        {'\xa0Data Compra\xa0': '\xa0'
#                                                                                'Data '
#                                                                                'Compra\xa0'},
#                                                        {'Modalidade da Compra': 'Modalidade '
#                                                                                 'da '
#                                                                                 'Compra'},
#                                                        {'\xa0Data Inserção': '\xa0'
#                                                                              'Data '
#                                                                              'Inserção'},
#                                                        {'Tipo Compra': 'Tipo '
#                                                                        'Compra'},
#                                                        {'Fabricante': 'Fabricante'},
#                                                        {'CNPJ Fabricante': 'CNPJ '
#                                                                            'Fabricante'},
#                                                        {'Fornecedor': 'Fornecedor'},
#                                                        {'CNPJ Fornecedor': 'CNPJ '
#                                                                            'Fornecedor'},
#                                                        {'Nome Instituição': 'Nome '
#                                                                             'Instituição'},
#                                                        {'CNPJ Instituição': 'CNPJ '
#                                                                             'Instituição'},
#                                                        {'Município Instituição': 'Município '
#                                                                                  'Instituição'},
#                                                        {'UF': 'UF'},
#                                                        {'Qtd Itens Comprados': 'Qtd '
#                                                                                'Itens '
#                                                                                'Comprados'},
#                                                        {'Preço Unitário': 'Preço '
#                                                                           'Unitário'},
#                                                        {'CMED - Preço Regulado': 'CMED '
#                                                                                  '- '
#                                                                                  'Preço '
#                                                                                  'Regulado'},
#                                                        {'Competência CMED': 'Competência '
#                                                                             'CMED'},
#                                                        {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                                    'Média '
#                                                                                    'Ponderada\xa0'}]},
#  {'BRAantineoplasticos1-BRAinsulina': [{'Código BR': 'Código BR'},
#                                        {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                'CATMAT'},
#                                        {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                            'Unidade '
#                                                                            'de '
#                                                                            'Fornecimento\xa0'},
#                                        {'Genérico': 'Genérico'},
#                                        {'Registro Anvisa': 'Registro Anvisa'},
#                                        {'\xa0Data Compra\xa0': '\xa0Data '
#                                                                'Compra\xa0'},
#                                        {'Modalidade da Compra': 'Modalidade da '
#                                                                 'Compra'},
#                                        {'\xa0Data Inserção': '\xa0Data '
#                                                              'Inserção'},
#                                        {'Tipo Compra': 'Tipo Compra'},
#                                        {'Fabricante': 'Fabricante'},
#                                        {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                        {'Fornecedor': 'Fornecedor'},
#                                        {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                        {'Nome Instituição': 'Nome Instituição'},
#                                        {'CNPJ Instituição': 'CNPJ Instituição'},
#                                        {'Município Instituição': 'Município '
#                                                                  'Instituição'},
#                                        {'UF': 'UF'},
#                                        {'Qtd Itens Comprados': 'Qtd Itens '
#                                                                'Comprados'},
#                                        {'Preço Unitário': 'Preço Unitário'},
#                                        {'CMED - Preço Regulado': 'CMED - Preço '
#                                                                  'Regulado'},
#                                        {'Competência CMED': 'Competência CMED'},
#                                        {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                                    'Ponderada\xa0'}]},
#  {'BRAantineoplasticos1-BRAlevotiroxina': [{'Código BR': 'Código BR'},
#                                            {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                    'CATMAT'},
#                                            {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                'Unidade '
#                                                                                'de '
#                                                                                'Fornecimento\xa0'},
#                                            {'Genérico': 'Genérico'},
#                                            {'Registro Anvisa': 'Registro '
#                                                                'Anvisa'},
#                                            {'\xa0Data Compra\xa0': '\xa0Data '
#                                                                    'Compra\xa0'},
#                                            {'Modalidade da Compra': 'Modalidade '
#                                                                     'da '
#                                                                     'Compra'},
#                                            {'\xa0Data Inserção': '\xa0Data '
#                                                                  'Inserção'},
#                                            {'Tipo Compra': 'Tipo Compra'},
#                                            {'Fabricante': 'Fabricante'},
#                                            {'CNPJ Fabricante': 'CNPJ '
#                                                                'Fabricante'},
#                                            {'Fornecedor': 'Fornecedor'},
#                                            {'CNPJ Fornecedor': 'CNPJ '
#                                                                'Fornecedor'},
#                                            {'Nome Instituição': 'Nome '
#                                                                 'Instituição'},
#                                            {'CNPJ Instituição': 'CNPJ '
#                                                                 'Instituição'},
#                                            {'Município Instituição': 'Município '
#                                                                      'Instituição'},
#                                            {'UF': 'UF'},
#                                            {'Qtd Itens Comprados': 'Qtd Itens '
#                                                                    'Comprados'},
#                                            {'Preço Unitário': 'Preço Unitário'},
#                                            {'CMED - Preço Regulado': 'CMED - '
#                                                                      'Preço '
#                                                                      'Regulado'},
#                                            {'Competência CMED': 'Competência '
#                                                                 'CMED'},
#                                            {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                        'Média '
#                                                                        'Ponderada\xa0'}]},
#  {'BRAantineoplasticos1-BRAmetformina': [{'Código BR': 'Código BR'},
#                                          {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                  'CATMAT'},
#                                          {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                              'Unidade '
#                                                                              'de '
#                                                                              'Fornecimento\xa0'},
#                                          {'Genérico': 'Genérico'},
#                                          {'Registro Anvisa': 'Registro Anvisa'},
#                                          {'\xa0Data Compra\xa0': '\xa0Data '
#                                                                  'Compra\xa0'},
#                                          {'Modalidade da Compra': 'Modalidade '
#                                                                   'da Compra'},
#                                          {'\xa0Data Inserção': '\xa0Data '
#                                                                'Inserção'},
#                                          {'Tipo Compra': 'Tipo Compra'},
#                                          {'Fabricante': 'Fabricante'},
#                                          {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                          {'Fornecedor': 'Fornecedor'},
#                                          {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                          {'Nome Instituição': 'Nome '
#                                                               'Instituição'},
#                                          {'CNPJ Instituição': 'CNPJ '
#                                                               'Instituição'},
#                                          {'Município Instituição': 'Município '
#                                                                    'Instituição'},
#                                          {'UF': 'UF'},
#                                          {'Qtd Itens Comprados': 'Qtd Itens '
#                                                                  'Comprados'},
#                                          {'Preço Unitário': 'Preço Unitário'},
#                                          {'CMED - Preço Regulado': 'CMED - '
#                                                                    'Preço '
#                                                                    'Regulado'},
#                                          {'Competência CMED': 'Competência '
#                                                               'CMED'},
#                                          {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                      'Média '
#                                                                      'Ponderada\xa0'}]},
#  {'BRAantineoplasticos2-BRAantineoplasticos3': [{'Código BR': 'Código BR'},
#                                                 {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                         'CATMAT'},
#                                                 {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                     'Unidade '
#                                                                                     'de '
#                                                                                     'Fornecimento\xa0'},
#                                                 {'Genérico': 'Genérico'},
#                                                 {'Registro Anvisa': 'Registro '
#                                                                     'Anvisa'},
#                                                 {'\xa0Data Compra\xa0': '\xa0'
#                                                                         'Data '
#                                                                         'Compra\xa0'},
#                                                 {'Modalidade da Compra': 'Modalidade '
#                                                                          'da '
#                                                                          'Compra'},
#                                                 {'\xa0Data Inserção': '\xa0'
#                                                                       'Data '
#                                                                       'Inserção'},
#                                                 {'Tipo Compra': 'Tipo Compra'},
#                                                 {'Fabricante': 'Fabricante'},
#                                                 {'CNPJ Fabricante': 'CNPJ '
#                                                                     'Fabricante'},
#                                                 {'Fornecedor': 'Fornecedor'},
#                                                 {'CNPJ Fornecedor': 'CNPJ '
#                                                                     'Fornecedor'},
#                                                 {'Nome Instituição': 'Nome '
#                                                                      'Instituição'},
#                                                 {'CNPJ Instituição': 'CNPJ '
#                                                                      'Instituição'},
#                                                 {'Município Instituição': 'Município '
#                                                                           'Instituição'},
#                                                 {'UF': 'UF'},
#                                                 {'Qtd Itens Comprados': 'Qtd '
#                                                                         'Itens '
#                                                                         'Comprados'},
#                                                 {'Preço Unitário': 'Preço '
#                                                                    'Unitário'},
#                                                 {'CMED - Preço Regulado': 'CMED '
#                                                                           '- '
#                                                                           'Preço '
#                                                                           'Regulado'},
#                                                 {'Competência CMED': 'Competência '
#                                                                      'CMED'},
#                                                 {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                             'Média '
#                                                                             'Ponderada\xa0'}]},
#  {'BRAantineoplasticos2-BRACardio1': [{'Código BR': 'Código BR'},
#                                       {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                               'CATMAT'},
#                                       {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                           'Unidade '
#                                                                           'de '
#                                                                           'Fornecimento\xa0'},
#                                       {'Genérico': 'Genérico'},
#                                       {'Registro Anvisa': 'Registro Anvisa'},
#                                       {'\xa0Data Compra\xa0': '\xa0Data '
#                                                               'Compra\xa0'},
#                                       {'Modalidade da Compra': 'Modalidade da '
#                                                                'Compra'},
#                                       {'\xa0Data Inserção': '\xa0Data '
#                                                             'Inserção'},
#                                       {'Tipo Compra': 'Tipo Compra'},
#                                       {'Fabricante': 'Fabricante'},
#                                       {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                       {'Fornecedor': 'Fornecedor'},
#                                       {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                       {'Nome Instituição': 'Nome Instituição'},
#                                       {'CNPJ Instituição': 'CNPJ Instituição'},
#                                       {'Município Instituição': 'Município '
#                                                                 'Instituição'},
#                                       {'UF': 'UF'},
#                                       {'Qtd Itens Comprados': 'Qtd Itens '
#                                                               'Comprados'},
#                                       {'Preço Unitário': 'Preço Unitário'},
#                                       {'CMED - Preço Regulado': 'CMED - Preço '
#                                                                 'Regulado'},
#                                       {'Competência CMED': 'Competência CMED'},
#                                       {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                                   'Ponderada\xa0'}]},
#  {'BRAantineoplasticos2-BRACardio2': [{'Código BR': 'Código BR'},
#                                       {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                               'CATMAT'},
#                                       {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                           'Unidade '
#                                                                           'de '
#                                                                           'Fornecimento\xa0'},
#                                       {'Genérico': 'Genérico'},
#                                       {'Registro Anvisa': 'Registro Anvisa'},
#                                       {'\xa0Data Compra\xa0': '\xa0Data '
#                                                               'Compra\xa0'},
#                                       {'Modalidade da Compra': 'Modalidade da '
#                                                                'Compra'},
#                                       {'\xa0Data Inserção': '\xa0Data '
#                                                             'Inserção'},
#                                       {'Tipo Compra': 'Tipo Compra'},
#                                       {'Fabricante': 'Fabricante'},
#                                       {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                       {'Fornecedor': 'Fornecedor'},
#                                       {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                       {'Nome Instituição': 'Nome Instituição'},
#                                       {'CNPJ Instituição': 'CNPJ Instituição'},
#                                       {'Município Instituição': 'Município '
#                                                                 'Instituição'},
#                                       {'UF': 'UF'},
#                                       {'Qtd Itens Comprados': 'Qtd Itens '
#                                                               'Comprados'},
#                                       {'Preço Unitário': 'Preço Unitário'},
#                                       {'CMED - Preço Regulado': 'CMED - Preço '
#                                                                 'Regulado'},
#                                       {'Competência CMED': 'Competência CMED'},
#                                       {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                                   'Ponderada\xa0'}]},
#  {'BRAantineoplasticos2-BRACardio3': [{'Código BR': 'Código BR'},
#                                       {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                               'CATMAT'},
#                                       {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                           'Unidade '
#                                                                           'de '
#                                                                           'Fornecimento\xa0'},
#                                       {'Genérico': 'Genérico'},
#                                       {'Registro Anvisa': 'Registro Anvisa'},
#                                       {'\xa0Data Compra\xa0': '\xa0Data '
#                                                               'Compra\xa0'},
#                                       {'Modalidade da Compra': 'Modalidade da '
#                                                                'Compra'},
#                                       {'\xa0Data Inserção': '\xa0Data '
#                                                             'Inserção'},
#                                       {'Tipo Compra': 'Tipo Compra'},
#                                       {'Fabricante': 'Fabricante'},
#                                       {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                       {'Fornecedor': 'Fornecedor'},
#                                       {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                       {'Nome Instituição': 'Nome Instituição'},
#                                       {'CNPJ Instituição': 'CNPJ Instituição'},
#                                       {'Município Instituição': 'Município '
#                                                                 'Instituição'},
#                                       {'UF': 'UF'},
#                                       {'Qtd Itens Comprados': 'Qtd Itens '
#                                                               'Comprados'},
#                                       {'Preço Unitário': 'Preço Unitário'},
#                                       {'CMED - Preço Regulado': 'CMED - Preço '
#                                                                 'Regulado'},
#                                       {'Competência CMED': 'Competência CMED'},
#                                       {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                                   'Ponderada\xa0'}]},
#  {'BRAantineoplasticos2-BRAfludrocortisona': [{'Código BR': 'Código BR'},
#                                               {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                       'CATMAT'},
#                                               {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                   'Unidade '
#                                                                                   'de '
#                                                                                   'Fornecimento\xa0'},
#                                               {'Genérico': 'Genérico'},
#                                               {'Registro Anvisa': 'Registro '
#                                                                   'Anvisa'},
#                                               {'\xa0Data Compra\xa0': '\xa0'
#                                                                       'Data '
#                                                                       'Compra\xa0'},
#                                               {'Modalidade da Compra': 'Modalidade '
#                                                                        'da '
#                                                                        'Compra'},
#                                               {'\xa0Data Inserção': '\xa0Data '
#                                                                     'Inserção'},
#                                               {'Tipo Compra': 'Tipo Compra'},
#                                               {'Fabricante': 'Fabricante'},
#                                               {'CNPJ Fabricante': 'CNPJ '
#                                                                   'Fabricante'},
#                                               {'Fornecedor': 'Fornecedor'},
#                                               {'CNPJ Fornecedor': 'CNPJ '
#                                                                   'Fornecedor'},
#                                               {'Nome Instituição': 'Nome '
#                                                                    'Instituição'},
#                                               {'CNPJ Instituição': 'CNPJ '
#                                                                    'Instituição'},
#                                               {'Município Instituição': 'Município '
#                                                                         'Instituição'},
#                                               {'UF': 'UF'},
#                                               {'Qtd Itens Comprados': 'Qtd '
#                                                                       'Itens '
#                                                                       'Comprados'},
#                                               {'Preço Unitário': 'Preço '
#                                                                  'Unitário'},
#                                               {'CMED - Preço Regulado': 'CMED '
#                                                                         '- '
#                                                                         'Preço '
#                                                                         'Regulado'},
#                                               {'Competência CMED': 'Competência '
#                                                                    'CMED'},
#                                               {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                           'Média '
#                                                                           'Ponderada\xa0'}]},
#  {'BRAantineoplasticos2-BRAglibenclamida-gliclazida': [{'Código BR': 'Código '
#                                                                      'BR'},
#                                                        {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                                'CATMAT'},
#                                                        {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                            'Unidade '
#                                                                                            'de '
#                                                                                            'Fornecimento\xa0'},
# ...
#                                                                         'Instituição'},
#                                               {'UF': 'UF'},
#                                               {'Qtd Itens Comprados': 'Qtd '
#                                                                       'Itens '
#                                                                       'Comprados'},
#                                               {'Preço Unitário': 'Preço '
#                                                                  'Unitário'},
#                                               {'CMED - Preço Regulado': 'CMED '
#                                                                         '- '
#                                                                         'Preço '
#                                                                         'Regulado'},
#                                               {'Competência CMED': 'Competência '
#                                                                    'CMED'},
#                                               {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                           'Média '
#                                                                           'Ponderada\xa0'}]},
#  {'BRAglibenclamida-gliclazida-BRAlevotiroxina': [{'Código BR': 'Código BR'},
#                                                   {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                           'CATMAT'},
#                                                   {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                       'Unidade '
#                                                                                       'de '
#                                                                                       'Fornecimento\xa0'},
#                                                   {'Genérico': 'Genérico'},
#                                                   {'Registro Anvisa': 'Registro '
#                                                                       'Anvisa'},
#                                                   {'\xa0Data Compra\xa0': '\xa0'
#                                                                           'Data '
#                                                                           'Compra\xa0'},
#                                                   {'Modalidade da Compra': 'Modalidade '
#                                                                            'da '
#                                                                            'Compra'},
#                                                   {'\xa0Data Inserção': '\xa0'
#                                                                         'Data '
#                                                                         'Inserção'},
#                                                   {'Tipo Compra': 'Tipo '
#                                                                   'Compra'},
#                                                   {'Fabricante': 'Fabricante'},
#                                                   {'CNPJ Fabricante': 'CNPJ '
#                                                                       'Fabricante'},
#                                                   {'Fornecedor': 'Fornecedor'},
#                                                   {'CNPJ Fornecedor': 'CNPJ '
#                                                                       'Fornecedor'},
#                                                   {'Nome Instituição': 'Nome '
#                                                                        'Instituição'},
#                                                   {'CNPJ Instituição': 'CNPJ '
#                                                                        'Instituição'},
#                                                   {'Município Instituição': 'Município '
#                                                                             'Instituição'},
#                                                   {'UF': 'UF'},
#                                                   {'Qtd Itens Comprados': 'Qtd '
#                                                                           'Itens '
#                                                                           'Comprados'},
#                                                   {'Preço Unitário': 'Preço '
#                                                                      'Unitário'},
#                                                   {'CMED - Preço Regulado': 'CMED '
#                                                                             '- '
#                                                                             'Preço '
#                                                                             'Regulado'},
#                                                   {'Competência CMED': 'Competência '
#                                                                        'CMED'},
#                                                   {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                               'Média '
#                                                                               'Ponderada\xa0'}]},
#  {'BRAglibenclamida-gliclazida-BRAmetformina': [{'Código BR': 'Código BR'},
#                                                 {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                         'CATMAT'},
#                                                 {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                     'Unidade '
#                                                                                     'de '
#                                                                                     'Fornecimento\xa0'},
#                                                 {'Genérico': 'Genérico'},
#                                                 {'Registro Anvisa': 'Registro '
#                                                                     'Anvisa'},
#                                                 {'\xa0Data Compra\xa0': '\xa0'
#                                                                         'Data '
#                                                                         'Compra\xa0'},
#                                                 {'Modalidade da Compra': 'Modalidade '
#                                                                          'da '
#                                                                          'Compra'},
#                                                 {'\xa0Data Inserção': '\xa0'
#                                                                       'Data '
#                                                                       'Inserção'},
#                                                 {'Tipo Compra': 'Tipo Compra'},
#                                                 {'Fabricante': 'Fabricante'},
#                                                 {'CNPJ Fabricante': 'CNPJ '
#                                                                     'Fabricante'},
#                                                 {'Fornecedor': 'Fornecedor'},
#                                                 {'CNPJ Fornecedor': 'CNPJ '
#                                                                     'Fornecedor'},
#                                                 {'Nome Instituição': 'Nome '
#                                                                      'Instituição'},
#                                                 {'CNPJ Instituição': 'CNPJ '
#                                                                      'Instituição'},
#                                                 {'Município Instituição': 'Município '
#                                                                           'Instituição'},
#                                                 {'UF': 'UF'},
#                                                 {'Qtd Itens Comprados': 'Qtd '
#                                                                         'Itens '
#                                                                         'Comprados'},
#                                                 {'Preço Unitário': 'Preço '
#                                                                    'Unitário'},
#                                                 {'CMED - Preço Regulado': 'CMED '
#                                                                           '- '
#                                                                           'Preço '
#                                                                           'Regulado'},
#                                                 {'Competência CMED': 'Competência '
#                                                                      'CMED'},
#                                                 {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                             'Média '
#                                                                             'Ponderada\xa0'}]},
#  {'BRAinsulina-BRAlevotiroxina': [{'Código BR': 'Código BR'},
#                                   {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                           'CATMAT'},
#                                   {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                       'Unidade '
#                                                                       'de '
#                                                                       'Fornecimento\xa0'},
#                                   {'Genérico': 'Genérico'},
#                                   {'Registro Anvisa': 'Registro Anvisa'},
#                                   {'\xa0Data Compra\xa0': '\xa0Data '
#                                                           'Compra\xa0'},
#                                   {'Modalidade da Compra': 'Modalidade da '
#                                                            'Compra'},
#                                   {'\xa0Data Inserção': '\xa0Data Inserção'},
#                                   {'Tipo Compra': 'Tipo Compra'},
#                                   {'Fabricante': 'Fabricante'},
#                                   {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                   {'Fornecedor': 'Fornecedor'},
#                                   {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                   {'Nome Instituição': 'Nome Instituição'},
#                                   {'CNPJ Instituição': 'CNPJ Instituição'},
#                                   {'Município Instituição': 'Município '
#                                                             'Instituição'},
#                                   {'UF': 'UF'},
#                                   {'Qtd Itens Comprados': 'Qtd Itens '
#                                                           'Comprados'},
#                                   {'Preço Unitário': 'Preço Unitário'},
#                                   {'CMED - Preço Regulado': 'CMED - Preço '
#                                                             'Regulado'},
#                                   {'Competência CMED': 'Competência CMED'},
#                                   {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                               'Ponderada\xa0'}]},
#  {'BRAinsulina-BRAmetformina': [{'Código BR': 'Código BR'},
#                                 {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'},
#                                 {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                     'Unidade '
#                                                                     'de '
#                                                                     'Fornecimento\xa0'},
#                                 {'Genérico': 'Genérico'},
#                                 {'Registro Anvisa': 'Registro Anvisa'},
#                                 {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'},
#                                 {'Modalidade da Compra': 'Modalidade da '
#                                                          'Compra'},
#                                 {'\xa0Data Inserção': '\xa0Data Inserção'},
#                                 {'Tipo Compra': 'Tipo Compra'},
#                                 {'Fabricante': 'Fabricante'},
#                                 {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                 {'Fornecedor': 'Fornecedor'},
#                                 {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                 {'Nome Instituição': 'Nome Instituição'},
#                                 {'CNPJ Instituição': 'CNPJ Instituição'},
#                                 {'Município Instituição': 'Município '
#                                                           'Instituição'},
#                                 {'UF': 'UF'},
#                                 {'Qtd Itens Comprados': 'Qtd Itens Comprados'},
#                                 {'Preço Unitário': 'Preço Unitário'},
#                                 {'CMED - Preço Regulado': 'CMED - Preço '
#                                                           'Regulado'},
#                                 {'Competência CMED': 'Competência CMED'},
#                                 {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                             'Ponderada\xa0'}]},
#  {'BRAlevotiroxina-BRAmetformina': [{'Código BR': 'Código BR'},
#                                     {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                             'CATMAT'},
#                                     {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                         'Unidade '
#                                                                         'de '
#                                                                         'Fornecimento\xa0'},
#                                     {'Genérico': 'Genérico'},
#                                     {'Registro Anvisa': 'Registro Anvisa'},
#                                     {'\xa0Data Compra\xa0': '\xa0Data '
#                                                             'Compra\xa0'},
#                                     {'Modalidade da Compra': 'Modalidade da '
#                                                              'Compra'},
#                                     {'\xa0Data Inserção': '\xa0Data Inserção'},
#                                     {'Tipo Compra': 'Tipo Compra'},
#                                     {'Fabricante': 'Fabricante'},
#                                     {'CNPJ Fabricante': 'CNPJ Fabricante'},
#                                     {'Fornecedor': 'Fornecedor'},
#                                     {'CNPJ Fornecedor': 'CNPJ Fornecedor'},
#                                     {'Nome Instituição': 'Nome Instituição'},
#                                     {'CNPJ Instituição': 'CNPJ Instituição'},
#                                     {'Município Instituição': 'Município '
#                                                               'Instituição'},
#                                     {'UF': 'UF'},
#                                     {'Qtd Itens Comprados': 'Qtd Itens '
#                                                             'Comprados'},
#                                     {'Preço Unitário': 'Preço Unitário'},
#                                     {'CMED - Preço Regulado': 'CMED - Preço '
#                                                               'Regulado'},
#                                     {'Competência CMED': 'Competência CMED'},
#                                     {'\xa0Média Ponderada\xa0': '\xa0Média '
#                                                                 'Ponderada\xa0'}]}]

# %%
print(len(BRA_mapping_res))
# Out:
# 55

# %% [markdown]
# ### Schema mapping within dataset CHL

# %%
CHL_files = ['CHLDiab1.csv', 'CHLDiab2.csv']

# %%
CHL_files_fp = [f'RAW Data/{ds}' for ds in CHL_files]
CHL_files_fp
# Out:
# ['RAW Data/CHLDiab1.csv', 'RAW Data/CHLDiab2.csv']

# %%
with open('RAW Data/CHLDiab1.csv', 'rb') as rawdata:
    res = chardet.detect(rawdata.read(100000))
CHL_enc = res['encoding']

# %%
CHL_col_list = []
for CHL_file in CHL_files_fp:
    CHL_data = pd.read_csv(CHL_file, header=0, encoding=CHL_enc)
    header = list(CHL_data.columns.values)
    CHL_col_list.append(header)
CHL_col_list
# Out:
# [['Unnamed: 0',
#   'Codigo',
#   'Tipo de Adquisicion',
#   'Estado',
#   'Nombre Organismo',
#   'Region Unidad',
#   'Codigo Moneda',
#   'Fecha Creacion',
#   'Fecha Publicacion',
#   'Fecha Adjudicacion',
#   'Fuente Financiamiento',
#   'Descripcion linea Adquisicion',
#   'Descripcion Proveedor',
#   'Unidad Medida',
#   'Nombre Proveedor',
#   'Estado Oferta',
#   'Cantidad Ofertada',
#   'Moneda de la Oferta',
#   'Monto Unitario Oferta',
#   'Valor Total Ofertado',
#   'Cantidad Adjudicada',
#   'Monto Linea Adjudica',
#   'Fecha Envio Oferta',
#   'Oferta seleccionada',
#   'CHL-USD',
#   'Monto Unitario Oferta USD',
#   'Monto Linea Adjudica USD',
#   'Valor Total Ofertado USD',
#   'Tipo de Institucion'],
#  ['Unnamed: 0',
#   'Codigo',
#   'Tipo de Adquisicion',
#   'Estado',
#   'Nombre Organismo',
#   'Region Unidad',
#   'Codigo Moneda',
#   'Fecha Creacion',
#   'Fecha Publicacion',
#   'Fecha Adjudicacion',
#   'Fuente Financiamiento',
#   'Descripcion linea Adquisicion',
#   'Descripcion Proveedor',
#   'Unidad Medida',
#   'Nombre Proveedor',
#   'Estado Oferta',
#   'Cantidad Ofertada',
#   'Moneda de la Oferta',
#   'Monto Unitario Oferta',
#   'Valor Total Ofertado',
#   'Cantidad Adjudicada',
#   'Monto Linea Adjudica',
#   'Fecha Envio Oferta',
#   'Oferta seleccionada',
#   'CHL-USD',
#   'Monto Unitario Oferta USD',
#   'Monto Linea Adjudica USD',
#   'Valor Total Ofertado USD',
#   'Tipo de Institucion']]

# %%
CHL_fp_headers = dict(zip(CHL_files_fp, CHL_col_list))

# %%
CHL_mapping_res = column_mapping(CHL_fp_headers)
# Out:
# pair {'Unnamed: 0': 'Unnamed: 0'}, the score is 100
# pair {'Codigo': 'Codigo'}, the score is 100
# pair {'Tipo de Adquisicion': 'Tipo de Adquisicion'}, the score is 100
# pair {'Estado': 'Estado'}, the score is 100
# pair {'Nombre Organismo': 'Nombre Organismo'}, the score is 100
# pair {'Region Unidad': 'Region Unidad'}, the score is 100
# pair {'Codigo Moneda': 'Codigo Moneda'}, the score is 100
# pair {'Fecha Creacion': 'Fecha Creacion'}, the score is 100
# pair {'Fecha Publicacion': 'Fecha Publicacion'}, the score is 100
# pair {'Fecha Adjudicacion': 'Fecha Adjudicacion'}, the score is 100
# pair {'Fuente Financiamiento': 'Fuente Financiamiento'}, the score is 100
# pair {'Descripcion linea Adquisicion': 'Descripcion linea Adquisicion'}, the score is 100
# pair {'Descripcion Proveedor': 'Descripcion Proveedor'}, the score is 100
# pair {'Unidad Medida': 'Unidad Medida'}, the score is 100
# pair {'Nombre Proveedor': 'Nombre Proveedor'}, the score is 100
# pair {'Estado Oferta': 'Estado Oferta'}, the score is 100
# pair {'Cantidad Ofertada': 'Cantidad Ofertada'}, the score is 100
# pair {'Moneda de la Oferta': 'Moneda de la Oferta'}, the score is 100
# pair {'Monto Unitario Oferta': 'Monto Unitario Oferta'}, the score is 100
# pair {'Valor Total Ofertado': 'Valor Total Ofertado'}, the score is 100
# pair {'Cantidad Adjudicada': 'Cantidad Adjudicada'}, the score is 100
# pair {'Monto Linea Adjudica': 'Monto Linea Adjudica'}, the score is 100
# pair {'Fecha Envio Oferta': 'Fecha Envio Oferta'}, the score is 100
# pair {'Oferta seleccionada': 'Oferta seleccionada'}, the score is 100
# pair {'CHL-USD': 'CHL-USD'}, the score is 100
# pair {'Monto Unitario Oferta USD': 'Monto Unitario Oferta USD'}, the score is 100
# pair {'Monto Linea Adjudica USD': 'Monto Linea Adjudica USD'}, the score is 100
# pair {'Valor Total Ofertado USD': 'Valor Total Ofertado USD'}, the score is 100
# pair {'Tipo de Institucion': 'Tipo de Institucion'}, the score is 100

# %%
pprint(CHL_mapping_res)
# Out:
# [{'CHLDiab1-CHLDiab2': [{'Unnamed: 0': 'Unnamed: 0'},
#                         {'Codigo': 'Codigo'},
#                         {'Tipo de Adquisicion': 'Tipo de Adquisicion'},
#                         {'Estado': 'Estado'},
#                         {'Nombre Organismo': 'Nombre Organismo'},
#                         {'Region Unidad': 'Region Unidad'},
#                         {'Codigo Moneda': 'Codigo Moneda'},
#                         {'Fecha Creacion': 'Fecha Creacion'},
#                         {'Fecha Publicacion': 'Fecha Publicacion'},
#                         {'Fecha Adjudicacion': 'Fecha Adjudicacion'},
#                         {'Fuente Financiamiento': 'Fuente Financiamiento'},
#                         {'Descripcion linea Adquisicion': 'Descripcion linea '
#                                                           'Adquisicion'},
#                         {'Descripcion Proveedor': 'Descripcion Proveedor'},
#                         {'Unidad Medida': 'Unidad Medida'},
#                         {'Nombre Proveedor': 'Nombre Proveedor'},
#                         {'Estado Oferta': 'Estado Oferta'},
#                         {'Cantidad Ofertada': 'Cantidad Ofertada'},
#                         {'Moneda de la Oferta': 'Moneda de la Oferta'},
#                         {'Monto Unitario Oferta': 'Monto Unitario Oferta'},
#                         {'Valor Total Ofertado': 'Valor Total Ofertado'},
#                         {'Cantidad Adjudicada': 'Cantidad Adjudicada'},
#                         {'Monto Linea Adjudica': 'Monto Linea Adjudica'},
#                         {'Fecha Envio Oferta': 'Fecha Envio Oferta'},
#                         {'Oferta seleccionada': 'Oferta seleccionada'},
#                         {'CHL-USD': 'CHL-USD'},
#                         {'Monto Unitario Oferta USD': 'Monto Unitario Oferta '
#                                                       'USD'},
#                         {'Monto Linea Adjudica USD': 'Monto Linea Adjudica '
#                                                      'USD'},
#                         {'Valor Total Ofertado USD': 'Valor Total Ofertado '
#                                                      'USD'},
#                         {'Tipo de Institucion': 'Tipo de Institucion'}]}]

# %% [markdown]
# ### Schema mapping within PER

# %%
PER_files = ['PERCardio Feb22.xls', 'PERantineoplastics1.xls', 'PERantineoplastics2.xls']

# %%
PER_files_fp = [f'RAW Data/{ds}' for ds in PER_files]
PER_files_fp
# Out:
# ['RAW Data/PERCardio Feb22.xls',
#  'RAW Data/PERantineoplastics1.xls',
#  'RAW Data/PERantineoplastics2.xls']

# %%
# encoding
with open('RAW Data/PERCardio Feb22.xls', 'rb') as rawdata:
    res = chardet.detect(rawdata.read(100000))
PER_enc = res['encoding']
PER_enc
# Out:
# 'windows-1253'

# %%
PER_col_list = []
for PER_file in PER_files_fp:
#     with open(PER_file, mode='r', encoding=PER_enc) as file:
    PER_data = pd.read_excel(PER_file, header=3)
    header = list(PER_data.columns.values)
    PER_col_list.append(header)
PER_col_list
# Out:
# [['RazonSocial',
#   'Código Entidad',
#   'Entidad',
#   'Código Disa/Diresa',
#   'Establecimiento',
#   'Código Unidad Ejecutora',
#   'Punto de Entrega',
#   'Identificación Proceso',
#   'Código Producto',
#   'Producto',
#   'Cantidad',
#   'Precio Unitario Referencial',
#   'Monto Total Referencial',
#   'Precio Unitario Ofertado',
#   'Monto Total Ofertado',
#   'Pais'],
#  ['RazonSocial',
#   'Código Entidad',
#   'Entidad',
#   'Código Disa/Diresa',
#   'Establecimiento',
#   'Código Unidad Ejecutora',
#   'Punto de Entrega',
#   'Identificación Proceso',
#   'Código Producto',
#   'Producto',
#   'Cantidad',
#   'Precio Unitario Referencial',
#   'Monto Total Referencial',
#   'Precio Unitario Ofertado',
#   'Monto Total Ofertado',
#   'Pais'],
#  ['RazonSocial',
#   'Código Entidad',
#   'Entidad',
#   'Código Disa/Diresa',
#   'Establecimiento',
#   'Código Unidad Ejecutora',
#   'Punto de Entrega',
#   'Identificación Proceso',
#   'Código Producto',
#   'Producto',
#   'Cantidad',
#   'Precio Unitario Referencial',
#   'Monto Total Referencial',
#   'Precio Unitario Ofertado',
#   'Monto Total Ofertado',
#   'Pais']]

# %%
PER_fp_headers = dict(zip(PER_files_fp, PER_col_list))

# %%
PER_mapping_res = column_mapping(PER_fp_headers)
# Out:
# pair {'RazonSocial': 'RazonSocial'}, the score is 100
# pair {'Código Entidad': 'Código Entidad'}, the score is 100
# pair {'Entidad': 'Entidad'}, the score is 100
# pair {'Código Disa/Diresa': 'Código Disa/Diresa'}, the score is 100
# pair {'Establecimiento': 'Establecimiento'}, the score is 100
# pair {'Código Unidad Ejecutora': 'Código Unidad Ejecutora'}, the score is 100
# pair {'Punto de Entrega': 'Punto de Entrega'}, the score is 100
# pair {'Identificación Proceso': 'Identificación Proceso'}, the score is 100
# pair {'Código Producto': 'Código Producto'}, the score is 100
# pair {'Producto': 'Producto'}, the score is 100
# pair {'Cantidad': 'Cantidad'}, the score is 100
# pair {'Precio Unitario Referencial': 'Precio Unitario Referencial'}, the score is 100
# pair {'Monto Total Referencial': 'Monto Total Referencial'}, the score is 100
# pair {'Precio Unitario Ofertado': 'Precio Unitario Ofertado'}, the score is 100
# pair {'Monto Total Ofertado': 'Monto Total Ofertado'}, the score is 100
# pair {'Pais': 'Pais'}, the score is 100
# pair {'RazonSocial': 'RazonSocial'}, the score is 100
# pair {'Código Entidad': 'Código Entidad'}, the score is 100
# pair {'Entidad': 'Entidad'}, the score is 100
# pair {'Código Disa/Diresa': 'Código Disa/Diresa'}, the score is 100
# pair {'Establecimiento': 'Establecimiento'}, the score is 100
# pair {'Código Unidad Ejecutora': 'Código Unidad Ejecutora'}, the score is 100
# pair {'Punto de Entrega': 'Punto de Entrega'}, the score is 100
# pair {'Identificación Proceso': 'Identificación Proceso'}, the score is 100
# pair {'Código Producto': 'Código Producto'}, the score is 100
# pair {'Producto': 'Producto'}, the score is 100
# pair {'Cantidad': 'Cantidad'}, the score is 100
# pair {'Precio Unitario Referencial': 'Precio Unitario Referencial'}, the score is 100
# pair {'Monto Total Referencial': 'Monto Total Referencial'}, the score is 100
# pair {'Precio Unitario Ofertado': 'Precio Unitario Ofertado'}, the score is 100
# pair {'Monto Total Ofertado': 'Monto Total Ofertado'}, the score is 100
# pair {'Pais': 'Pais'}, the score is 100
# pair {'RazonSocial': 'RazonSocial'}, the score is 100
# pair {'Código Entidad': 'Código Entidad'}, the score is 100
# pair {'Entidad': 'Entidad'}, the score is 100
# pair {'Código Disa/Diresa': 'Código Disa/Diresa'}, the score is 100
# pair {'Establecimiento': 'Establecimiento'}, the score is 100
# pair {'Código Unidad Ejecutora': 'Código Unidad Ejecutora'}, the score is 100
# pair {'Punto de Entrega': 'Punto de Entrega'}, the score is 100
# pair {'Identificación Proceso': 'Identificación Proceso'}, the score is 100
# pair {'Código Producto': 'Código Producto'}, the score is 100
# pair {'Producto': 'Producto'}, the score is 100
# pair {'Cantidad': 'Cantidad'}, the score is 100
# pair {'Precio Unitario Referencial': 'Precio Unitario Referencial'}, the score is 100
# pair {'Monto Total Referencial': 'Monto Total Referencial'}, the score is 100
# pair {'Precio Unitario Ofertado': 'Precio Unitario Ofertado'}, the score is 100
# pair {'Monto Total Ofertado': 'Monto Total Ofertado'}, the score is 100
# pair {'Pais': 'Pais'}, the score is 100

# %%
pprint(PER_mapping_res)
# Out:
# [{'PERCardio Feb22-PERantineoplastics1': [{'RazonSocial': 'RazonSocial'},
#                                           {'Código Entidad': 'Código Entidad'},
#                                           {'Entidad': 'Entidad'},
#                                           {'Código Disa/Diresa': 'Código '
#                                                                  'Disa/Diresa'},
#                                           {'Establecimiento': 'Establecimiento'},
#                                           {'Código Unidad Ejecutora': 'Código '
#                                                                       'Unidad '
#                                                                       'Ejecutora'},
#                                           {'Punto de Entrega': 'Punto de '
#                                                                'Entrega'},
#                                           {'Identificación Proceso': 'Identificación '
#                                                                      'Proceso'},
#                                           {'Código Producto': 'Código '
#                                                               'Producto'},
#                                           {'Producto': 'Producto'},
#                                           {'Cantidad': 'Cantidad'},
#                                           {'Precio Unitario Referencial': 'Precio '
#                                                                           'Unitario '
#                                                                           'Referencial'},
#                                           {'Monto Total Referencial': 'Monto '
#                                                                       'Total '
#                                                                       'Referencial'},
#                                           {'Precio Unitario Ofertado': 'Precio '
#                                                                        'Unitario '
#                                                                        'Ofertado'},
#                                           {'Monto Total Ofertado': 'Monto '
#                                                                    'Total '
#                                                                    'Ofertado'},
#                                           {'Pais': 'Pais'}]},
#  {'PERCardio Feb22-PERantineoplastics2': [{'RazonSocial': 'RazonSocial'},
#                                           {'Código Entidad': 'Código Entidad'},
#                                           {'Entidad': 'Entidad'},
#                                           {'Código Disa/Diresa': 'Código '
#                                                                  'Disa/Diresa'},
#                                           {'Establecimiento': 'Establecimiento'},
#                                           {'Código Unidad Ejecutora': 'Código '
#                                                                       'Unidad '
#                                                                       'Ejecutora'},
#                                           {'Punto de Entrega': 'Punto de '
#                                                                'Entrega'},
#                                           {'Identificación Proceso': 'Identificación '
#                                                                      'Proceso'},
#                                           {'Código Producto': 'Código '
#                                                               'Producto'},
#                                           {'Producto': 'Producto'},
#                                           {'Cantidad': 'Cantidad'},
#                                           {'Precio Unitario Referencial': 'Precio '
#                                                                           'Unitario '
#                                                                           'Referencial'},
#                                           {'Monto Total Referencial': 'Monto '
#                                                                       'Total '
#                                                                       'Referencial'},
#                                           {'Precio Unitario Ofertado': 'Precio '
#                                                                        'Unitario '
#                                                                        'Ofertado'},
#                                           {'Monto Total Ofertado': 'Monto '
#                                                                    'Total '
#                                                                    'Ofertado'},
#                                           {'Pais': 'Pais'}]},
#  {'PERantineoplastics1-PERantineoplastics2': [{'RazonSocial': 'RazonSocial'},
#                                               {'Código Entidad': 'Código '
#                                                                  'Entidad'},
#                                               {'Entidad': 'Entidad'},
#                                               {'Código Disa/Diresa': 'Código '
#                                                                      'Disa/Diresa'},
#                                               {'Establecimiento': 'Establecimiento'},
#                                               {'Código Unidad Ejecutora': 'Código '
#                                                                           'Unidad '
#                                                                           'Ejecutora'},
#                                               {'Punto de Entrega': 'Punto de '
#                                                                    'Entrega'},
#                                               {'Identificación Proceso': 'Identificación '
#                                                                          'Proceso'},
#                                               {'Código Producto': 'Código '
#                                                                   'Producto'},
#                                               {'Producto': 'Producto'},
#                                               {'Cantidad': 'Cantidad'},
#                                               {'Precio Unitario Referencial': 'Precio '
#                                                                               'Unitario '
#                                                                               'Referencial'},
#                                               {'Monto Total Referencial': 'Monto '
#                                                                           'Total '
#                                                                           'Referencial'},
#                                               {'Precio Unitario Ofertado': 'Precio '
#                                                                            'Unitario '
#                                                                            'Ofertado'},
#                                               {'Monto Total Ofertado': 'Monto '
#                                                                        'Total '
#                                                                        'Ofertado'},
#                                               {'Pais': 'Pais'}]}]

# %% [markdown]
# ### Schema mapping BRA and other files

# %%
BRA_headers = dict(list(BRA_fp_headers.items())[:1])
CHL_headers = dict(list(CHL_fp_headers.items())[:1])
PER_headers = dict(list(PER_fp_headers.items())[:1])

# %%
PER_headers
# Out:
# {'RAW Data/PERCardio Feb22.xls': ['RazonSocial',
#   'Código Entidad',
#   'Entidad',
#   'Código Disa/Diresa',
#   'Establecimiento',
#   'Código Unidad Ejecutora',
#   'Punto de Entrega',
#   'Identificación Proceso',
#   'Código Producto',
#   'Producto',
#   'Cantidad',
#   'Precio Unitario Referencial',
#   'Monto Total Referencial',
#   'Precio Unitario Ofertado',
#   'Monto Total Ofertado',
#   'Pais']}

# %%
DOMC_files = ['Raw Data/DOMComprasCardio.csv']

with open('Raw Data/DOMComprasCardio.csv', 'rb') as rawdata:
    res = chardet.detect(rawdata.read(100000))
DOMC_enc = res['encoding']
DOMC_enc
# Out:
# 'utf-8'

# %%
DOMC_col_list = []
for DOMC_file in DOMC_files:
    DOMC_data = pd.read_csv(DOMC_file, header=0, encoding=DOMC_enc)
    header = list(data.columns.values)
    DOMC_col_list.append(header)
DOMC_fp_headers = dict(zip(DOMC_files, DOMC_col_list))

# %%
DOMC_headers = dict(list(DOMC_fp_headers.items())[:1])
DOMC_headers
# Out:
# {'Raw Data/DOMComprasCardio.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0']}

# %%
merge_dict = {}
merge_dict.update(BRA_headers)
merge_dict.update(CHL_headers)
merge_dict.update(PER_headers)
merge_dict.update(DOMC_headers)

# %%
merge_dict
# Out:
# {'RAW Data/BRAantineoplasticos1.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0'],
#  'RAW Data/CHLDiab1.csv': ['Unnamed: 0',
#   'Codigo',
#   'Tipo de Adquisicion',
#   'Estado',
#   'Nombre Organismo',
#   'Region Unidad',
#   'Codigo Moneda',
#   'Fecha Creacion',
#   'Fecha Publicacion',
#   'Fecha Adjudicacion',
#   'Fuente Financiamiento',
#   'Descripcion linea Adquisicion',
#   'Descripcion Proveedor',
#   'Unidad Medida',
#   'Nombre Proveedor',
#   'Estado Oferta',
#   'Cantidad Ofertada',
#   'Moneda de la Oferta',
#   'Monto Unitario Oferta',
#   'Valor Total Ofertado',
#   'Cantidad Adjudicada',
#   'Monto Linea Adjudica',
#   'Fecha Envio Oferta',
#   'Oferta seleccionada',
#   'CHL-USD',
#   'Monto Unitario Oferta USD',
#   'Monto Linea Adjudica USD',
#   'Valor Total Ofertado USD',
#   'Tipo de Institucion'],
#  'RAW Data/PERCardio Feb22.xls': ['RazonSocial',
#   'Código Entidad',
#   'Entidad',
#   'Código Disa/Diresa',
#   'Establecimiento',
#   'Código Unidad Ejecutora',
#   'Punto de Entrega',
#   'Identificación Proceso',
#   'Código Producto',
#   'Producto',
#   'Cantidad',
#   'Precio Unitario Referencial',
#   'Monto Total Referencial',
#   'Precio Unitario Ofertado',
#   'Monto Total Ofertado',
#   'Pais'],
#  'Raw Data/DOMComprasCardio.csv': ['Código BR',
#   'Descrição\xa0CATMAT',
#   '\xa0Unidade de Fornecimento\xa0',
#   'Genérico',
#   'Registro Anvisa',
#   '\xa0Data Compra\xa0',
#   'Modalidade da Compra',
#   '\xa0Data Inserção',
#   'Tipo Compra',
#   'Fabricante',
#   'CNPJ Fabricante',
#   'Fornecedor',
#   'CNPJ Fornecedor',
#   'Nome Instituição',
#   'CNPJ Instituição',
#   'Município Instituição',
#   'UF',
#   'Qtd Itens Comprados',
#   'Preço Unitário',
#   'CMED - Preço Regulado',
#   'Competência CMED',
#   '\xa0Média Ponderada\xa0']}

# %%
merge_mapping_res = column_mapping(merge_dict)
# Out:
# pair {'Código BR': 'Codigo'}, the score is 67
# pair {'Descrição\xa0CATMAT': 'Descripcion linea Adquisicion'}, the score is 40
# pair {'\xa0Unidade de Fornecimento\xa0': 'Fuente Financiamiento'}, the score is 57
# pair {'Genérico': 'Tipo de Institucion'}, the score is 37
# pair {'Registro Anvisa': 'Region Unidad'}, the score is 64
# pair {'\xa0Data Compra\xa0': 'Cantidad Ofertada'}, the score is 47
# pair {'Modalidade da Compra': 'Moneda de la Oferta'}, the score is 62
# pair {'\xa0Data Inserção': 'Valor Total Ofertado'}, the score is 41
# pair {'Tipo Compra': 'Estado Oferta'}, the score is 50
# pair {'Fabricante': 'Fecha Publicacion'}, the score is 52
# pair {'CNPJ Fabricante': 'Fecha Publicacion'}, the score is 44
# pair {'Fornecedor': 'Nombre Proveedor'}, the score is 54
# pair {'CNPJ Fornecedor': 'Nombre Proveedor'}, the score is 52
# pair {'Nome Instituição': 'Tipo de Institucion'}, the score is 69
# pair {'CNPJ Instituição': 'Tipo de Institucion'}, the score is 63
# pair {'Município Instituição': 'Tipo de Institucion'}, the score is 65
# pair {'UF': 'CHL-USD'}, the score is 22
# pair {'Qtd Itens Comprados': 'Descripcion Proveedor'}, the score is 45
# pair {'Preço Unitário': 'Region Unidad'}, the score is 52
# pair {'CMED - Preço Regulado': 'Nombre Proveedor'}, the score is 49
# pair {'Competência CMED': 'Codigo Moneda'}, the score is 48
# pair {'\xa0Média Ponderada\xa0': 'Codigo Moneda'}, the score is 53
# pair {'Código BR': 'Código Producto'}, the score is 67
# pair {'Descrição\xa0CATMAT': 'Establecimiento'}, the score is 39
# pair {'\xa0Unidade de Fornecimento\xa0': 'Código Unidad Ejecutora'}, the score is 50
# pair {'Genérico': 'Entidad'}, the score is 40
# pair {'Registro Anvisa': 'Precio Unitario Referencial'}, the score is 48
# pair {'\xa0Data Compra\xa0': 'Código Unidad Ejecutora'}, the score is 39
# pair {'Modalidade da Compra': 'Código Unidad Ejecutora'}, the score is 47
# pair {'\xa0Data Inserção': 'Identificación Proceso'}, the score is 39
# pair {'Tipo Compra': 'Producto'}, the score is 42
# pair {'Fabricante': 'Cantidad'}, the score is 44
# pair {'CNPJ Fabricante': 'Identificación Proceso'}, the score is 38
# pair {'Fornecedor': 'Código Unidad Ejecutora'}, the score is 36
# pair {'CNPJ Fornecedor': 'Identificación Proceso'}, the score is 38
# pair {'Nome Instituição': 'Establecimiento'}, the score is 39
# pair {'CNPJ Instituição': 'Precio Unitario Ofertado'}, the score is 35
# pair {'Município Instituição': 'Código Entidad'}, the score is 40
# pair {'UF': 'Producto'}, the score is 20
# pair {'Qtd Itens Comprados': 'Monto Total Ofertado'}, the score is 46
# pair {'Preço Unitário': 'Precio Unitario Ofertado'}, the score is 63
# pair {'CMED - Preço Regulado': 'Código Producto'}, the score is 44
# pair {'Competência CMED': 'Código Entidad'}, the score is 47
# pair {'\xa0Média Ponderada\xa0': 'Código Entidad'}, the score is 45
# pair {'Código BR': 'Código BR'}, the score is 100
# pair {'Descrição\xa0CATMAT': 'Descrição\xa0CATMAT'}, the score is 100
# pair {'\xa0Unidade de Fornecimento\xa0': '\xa0Unidade de Fornecimento\xa0'}, the score is 100
# pair {'Genérico': 'Genérico'}, the score is 100
# pair {'Registro Anvisa': 'Registro Anvisa'}, the score is 100
# pair {'\xa0Data Compra\xa0': '\xa0Data Compra\xa0'}, the score is 100
# pair {'Modalidade da Compra': 'Modalidade da Compra'}, the score is 100
# pair {'\xa0Data Inserção': '\xa0Data Inserção'}, the score is 100
# pair {'Tipo Compra': 'Tipo Compra'}, the score is 100
# pair {'Fabricante': 'Fabricante'}, the score is 100
# pair {'CNPJ Fabricante': 'CNPJ Fabricante'}, the score is 100
# pair {'Fornecedor': 'Fornecedor'}, the score is 100
# pair {'CNPJ Fornecedor': 'CNPJ Fornecedor'}, the score is 100
# pair {'Nome Instituição': 'Nome Instituição'}, the score is 100
# pair {'CNPJ Instituição': 'CNPJ Instituição'}, the score is 100
# pair {'Município Instituição': 'Município Instituição'}, the score is 100
# pair {'UF': 'UF'}, the score is 100
# pair {'Qtd Itens Comprados': 'Qtd Itens Comprados'}, the score is 100
# pair {'Preço Unitário': 'Preço Unitário'}, the score is 100
# pair {'CMED - Preço Regulado': 'CMED - Preço Regulado'}, the score is 100
# pair {'Competência CMED': 'Competência CMED'}, the score is 100
# pair {'\xa0Média Ponderada\xa0': '\xa0Média Ponderada\xa0'}, the score is 100
# pair {'Unnamed: 0': 'Entidad'}, the score is 35
# pair {'Codigo': 'Código Entidad'}, the score is 50
# pair {'Tipo de Adquisicion': 'Producto'}, the score is 44
# pair {'Estado': 'Entidad'}, the score is 62
# pair {'Nombre Organismo': 'Punto de Entrega'}, the score is 44
# pair {'Region Unidad': 'Entidad'}, the score is 60
# pair {'Codigo Moneda': 'Código Entidad'}, the score is 67
# pair {'Fecha Creacion': 'Establecimiento'}, the score is 41
# pair {'Fecha Publicacion': 'Establecimiento'}, the score is 44
# pair {'Fecha Adjudicacion': 'Precio Unitario Referencial'}, the score is 40
# pair {'Fuente Financiamiento': 'Establecimiento'}, the score is 61
# pair {'Descripcion linea Adquisicion': 'Precio Unitario Ofertado'}, the score is 42
# pair {'Descripcion Proveedor': 'Identificación Proceso'}, the score is 56
# pair {'Unidad Medida': 'Entidad'}, the score is 50
# pair {'Nombre Proveedor': 'Código Producto'}, the score is 45
# pair {'Estado Oferta': 'Precio Unitario Ofertado'}, the score is 59
# pair {'Cantidad Ofertada': 'Cantidad'}, the score is 64
# pair {'Moneda de la Oferta': 'Monto Total Ofertado'}, the score is 62
# pair {'Monto Unitario Oferta': 'Precio Unitario Ofertado'}, the score is 76
# pair {'Valor Total Ofertado': 'Monto Total Ofertado'}, the score is 80
# pair {'Cantidad Adjudicada': 'Cantidad'}, the score is 59
# pair {'Monto Linea Adjudica': 'Monto Total Ofertado'}, the score is 50
# pair {'Fecha Envio Oferta': 'Precio Unitario Ofertado'}, the score is 62
# pair {'Oferta seleccionada': 'Establecimiento'}, the score is 47
# pair {'CHL-USD': 'Cantidad'}, the score is 27
# pair {'Monto Unitario Oferta USD': 'Precio Unitario Ofertado'}, the score is 73
# pair {'Monto Linea Adjudica USD': 'Monto Total Ofertado'}, the score is 45
# pair {'Valor Total Ofertado USD': 'Monto Total Ofertado'}, the score is 73
# pair {'Tipo de Institucion': 'Punto de Entrega'}, the score is 46
# pair {'Unnamed: 0': 'Competência CMED'}, the score is 38
# pair {'Codigo': 'Código BR'}, the score is 67
# pair {'Tipo de Adquisicion': 'Tipo Compra'}, the score is 47
# pair {'Estado': 'Qtd Itens Comprados'}, the score is 40
# pair {'Nombre Organismo': 'Nome Instituição'}, the score is 50
# pair {'Region Unidad': 'Registro Anvisa'}, the score is 64
# pair {'Codigo Moneda': 'Código BR'}, the score is 55
# pair {'Fecha Creacion': 'Fabricante'}, the score is 42
# pair {'Fecha Publicacion': 'Fabricante'}, the score is 52
# pair {'Fecha Adjudicacion': 'Fabricante'}, the score is 43
# pair {'Fuente Financiamiento': '\xa0Unidade de Fornecimento\xa0'}, the score is 57
# pair {'Descripcion linea Adquisicion': 'Município Instituição'}, the score is 44
# pair {'Descripcion Proveedor': 'CNPJ Fornecedor'}, the score is 50
# pair {'Unidad Medida': 'Competência CMED'}, the score is 48
# pair {'Nombre Proveedor': 'Fornecedor'}, the score is 54
# pair {'Estado Oferta': 'Tipo Compra'}, the score is 50
# pair {'Cantidad Ofertada': '\xa0Média Ponderada\xa0'}, the score is 53
# pair {'Moneda de la Oferta': 'Modalidade da Compra'}, the score is 62
# pair {'Monto Unitario Oferta': 'Preço Unitário'}, the score is 51
# pair {'Valor Total Ofertado': '\xa0Data Compra\xa0'}, the score is 42
# pair {'Cantidad Adjudicada': 'Modalidade da Compra'}, the score is 46
# pair {'Monto Linea Adjudica': 'Modalidade da Compra'}, the score is 45
# pair {'Fecha Envio Oferta': 'Fornecedor'}, the score is 43
# pair {'Oferta seleccionada': 'Descrição\xa0CATMAT'}, the score is 40
# pair {'CHL-USD': 'CMED - Preço Regulado'}, the score is 29
# pair {'Monto Unitario Oferta USD': 'Preço Unitário'}, the score is 46
# pair {'Monto Linea Adjudica USD': 'Modalidade da Compra'}, the score is 41
# pair {'Valor Total Ofertado USD': 'Qtd Itens Comprados'}, the score is 42
# pair {'Tipo de Institucion': 'Nome Instituição'}, the score is 69
# pair {'RazonSocial': 'Registro Anvisa'}, the score is 38
# pair {'Código Entidad': 'Código BR'}, the score is 61
# pair {'Entidad': 'Competência CMED'}, the score is 43
# pair {'Código Disa/Diresa': 'Código BR'}, the score is 59
# pair {'Establecimiento': '\xa0Unidade de Fornecimento\xa0'}, the score is 45
# pair {'Código Unidad Ejecutora': 'Código BR'}, the score is 50
# pair {'Punto de Entrega': '\xa0Unidade de Fornecimento\xa0'}, the score is 44
# pair {'Identificación Proceso': '\xa0Data Inserção'}, the score is 39
# pair {'Código Producto': 'Código BR'}, the score is 67
# pair {'Producto': 'Preço Unitário'}, the score is 55
# pair {'Cantidad': 'Fabricante'}, the score is 44
# pair {'Precio Unitario Referencial': 'Preço Unitário'}, the score is 59
# pair {'Monto Total Referencial': '\xa0Unidade de Fornecimento\xa0'}, the score is 38
# pair {'Precio Unitario Ofertado': 'Preço Unitário'}, the score is 63
# pair {'Monto Total Ofertado': 'Qtd Itens Comprados'}, the score is 46
# pair {'Pais': '\xa0Data Inserção'}, the score is 33

# %%
pprint(merge_mapping_res)
# Out:
# [{'BRAantineoplasticos1-CHLDiab1': [{'Código BR': 'Codigo'},
#                                     {'Descrição\xa0CATMAT': 'Descripcion linea '
#                                                             'Adquisicion'},
#                                     {'\xa0Unidade de Fornecimento\xa0': 'Fuente '
#                                                                         'Financiamiento'},
#                                     {'Genérico': 'Tipo de Institucion'},
#                                     {'Registro Anvisa': 'Region Unidad'},
#                                     {'\xa0Data Compra\xa0': 'Cantidad '
#                                                             'Ofertada'},
#                                     {'Modalidade da Compra': 'Moneda de la '
#                                                              'Oferta'},
#                                     {'\xa0Data Inserção': 'Valor Total '
#                                                           'Ofertado'},
#                                     {'Tipo Compra': 'Estado Oferta'},
#                                     {'Fabricante': 'Fecha Publicacion'},
#                                     {'CNPJ Fabricante': 'Fecha Publicacion'},
#                                     {'Fornecedor': 'Nombre Proveedor'},
#                                     {'CNPJ Fornecedor': 'Nombre Proveedor'},
#                                     {'Nome Instituição': 'Tipo de Institucion'},
#                                     {'CNPJ Instituição': 'Tipo de Institucion'},
#                                     {'Município Instituição': 'Tipo de '
#                                                               'Institucion'},
#                                     {'UF': 'CHL-USD'},
#                                     {'Qtd Itens Comprados': 'Descripcion '
#                                                             'Proveedor'},
#                                     {'Preço Unitário': 'Region Unidad'},
#                                     {'CMED - Preço Regulado': 'Nombre '
#                                                               'Proveedor'},
#                                     {'Competência CMED': 'Codigo Moneda'},
#                                     {'\xa0Média Ponderada\xa0': 'Codigo '
#                                                                 'Moneda'}]},
#  {'BRAantineoplasticos1-PERCardio Feb22': [{'Código BR': 'Código Producto'},
#                                            {'Descrição\xa0CATMAT': 'Establecimiento'},
#                                            {'\xa0Unidade de Fornecimento\xa0': 'Código '
#                                                                                'Unidad '
#                                                                                'Ejecutora'},
#                                            {'Genérico': 'Entidad'},
#                                            {'Registro Anvisa': 'Precio '
#                                                                'Unitario '
#                                                                'Referencial'},
#                                            {'\xa0Data Compra\xa0': 'Código '
#                                                                    'Unidad '
#                                                                    'Ejecutora'},
#                                            {'Modalidade da Compra': 'Código '
#                                                                     'Unidad '
#                                                                     'Ejecutora'},
#                                            {'\xa0Data Inserção': 'Identificación '
#                                                                  'Proceso'},
#                                            {'Tipo Compra': 'Producto'},
#                                            {'Fabricante': 'Cantidad'},
#                                            {'CNPJ Fabricante': 'Identificación '
#                                                                'Proceso'},
#                                            {'Fornecedor': 'Código Unidad '
#                                                           'Ejecutora'},
#                                            {'CNPJ Fornecedor': 'Identificación '
#                                                                'Proceso'},
#                                            {'Nome Instituição': 'Establecimiento'},
#                                            {'CNPJ Instituição': 'Precio '
#                                                                 'Unitario '
#                                                                 'Ofertado'},
#                                            {'Município Instituição': 'Código '
#                                                                      'Entidad'},
#                                            {'UF': 'Producto'},
#                                            {'Qtd Itens Comprados': 'Monto '
#                                                                    'Total '
#                                                                    'Ofertado'},
#                                            {'Preço Unitário': 'Precio Unitario '
#                                                               'Ofertado'},
#                                            {'CMED - Preço Regulado': 'Código '
#                                                                      'Producto'},
#                                            {'Competência CMED': 'Código '
#                                                                 'Entidad'},
#                                            {'\xa0Média Ponderada\xa0': 'Código '
#                                                                        'Entidad'}]},
#  {'BRAantineoplasticos1-DOMComprasCardio': [{'Código BR': 'Código BR'},
#                                             {'Descrição\xa0CATMAT': 'Descrição\xa0'
#                                                                     'CATMAT'},
#                                             {'\xa0Unidade de Fornecimento\xa0': '\xa0'
#                                                                                 'Unidade '
#                                                                                 'de '
#                                                                                 'Fornecimento\xa0'},
#                                             {'Genérico': 'Genérico'},
#                                             {'Registro Anvisa': 'Registro '
#                                                                 'Anvisa'},
#                                             {'\xa0Data Compra\xa0': '\xa0Data '
#                                                                     'Compra\xa0'},
#                                             {'Modalidade da Compra': 'Modalidade '
#                                                                      'da '
#                                                                      'Compra'},
#                                             {'\xa0Data Inserção': '\xa0Data '
#                                                                   'Inserção'},
#                                             {'Tipo Compra': 'Tipo Compra'},
#                                             {'Fabricante': 'Fabricante'},
#                                             {'CNPJ Fabricante': 'CNPJ '
#                                                                 'Fabricante'},
#                                             {'Fornecedor': 'Fornecedor'},
#                                             {'CNPJ Fornecedor': 'CNPJ '
#                                                                 'Fornecedor'},
#                                             {'Nome Instituição': 'Nome '
#                                                                  'Instituição'},
#                                             {'CNPJ Instituição': 'CNPJ '
#                                                                  'Instituição'},
#                                             {'Município Instituição': 'Município '
#                                                                       'Instituição'},
#                                             {'UF': 'UF'},
#                                             {'Qtd Itens Comprados': 'Qtd Itens '
#                                                                     'Comprados'},
#                                             {'Preço Unitário': 'Preço '
#                                                                'Unitário'},
#                                             {'CMED - Preço Regulado': 'CMED - '
#                                                                       'Preço '
#                                                                       'Regulado'},
#                                             {'Competência CMED': 'Competência '
#                                                                  'CMED'},
#                                             {'\xa0Média Ponderada\xa0': '\xa0'
#                                                                         'Média '
#                                                                         'Ponderada\xa0'}]},
#  {'CHLDiab1-PERCardio Feb22': [{'Unnamed: 0': 'Entidad'},
#                                {'Codigo': 'Código Entidad'},
#                                {'Tipo de Adquisicion': 'Producto'},
#                                {'Estado': 'Entidad'},
#                                {'Nombre Organismo': 'Punto de Entrega'},
#                                {'Region Unidad': 'Entidad'},
#                                {'Codigo Moneda': 'Código Entidad'},
#                                {'Fecha Creacion': 'Establecimiento'},
#                                {'Fecha Publicacion': 'Establecimiento'},
#                                {'Fecha Adjudicacion': 'Precio Unitario '
#                                                       'Referencial'},
#                                {'Fuente Financiamiento': 'Establecimiento'},
#                                {'Descripcion linea Adquisicion': 'Precio '
#                                                                  'Unitario '
#                                                                  'Ofertado'},
#                                {'Descripcion Proveedor': 'Identificación '
#                                                          'Proceso'},
#                                {'Unidad Medida': 'Entidad'},
#                                {'Nombre Proveedor': 'Código Producto'},
#                                {'Estado Oferta': 'Precio Unitario Ofertado'},
#                                {'Cantidad Ofertada': 'Cantidad'},
#                                {'Moneda de la Oferta': 'Monto Total Ofertado'},
#                                {'Monto Unitario Oferta': 'Precio Unitario '
#                                                          'Ofertado'},
#                                {'Valor Total Ofertado': 'Monto Total Ofertado'},
#                                {'Cantidad Adjudicada': 'Cantidad'},
#                                {'Monto Linea Adjudica': 'Monto Total Ofertado'},
#                                {'Fecha Envio Oferta': 'Precio Unitario '
#                                                       'Ofertado'},
#                                {'Oferta seleccionada': 'Establecimiento'},
#                                {'CHL-USD': 'Cantidad'},
#                                {'Monto Unitario Oferta USD': 'Precio Unitario '
#                                                              'Ofertado'},
#                                {'Monto Linea Adjudica USD': 'Monto Total '
#                                                             'Ofertado'},
#                                {'Valor Total Ofertado USD': 'Monto Total '
#                                                             'Ofertado'},
#                                {'Tipo de Institucion': 'Punto de Entrega'}]},
#  {'CHLDiab1-DOMComprasCardio': [{'Unnamed: 0': 'Competência CMED'},
#                                 {'Codigo': 'Código BR'},
#                                 {'Tipo de Adquisicion': 'Tipo Compra'},
#                                 {'Estado': 'Qtd Itens Comprados'},
#                                 {'Nombre Organismo': 'Nome Instituição'},
#                                 {'Region Unidad': 'Registro Anvisa'},
#                                 {'Codigo Moneda': 'Código BR'},
#                                 {'Fecha Creacion': 'Fabricante'},
#                                 {'Fecha Publicacion': 'Fabricante'},
#                                 {'Fecha Adjudicacion': 'Fabricante'},
#                                 {'Fuente Financiamiento': '\xa0Unidade de '
#                                                           'Fornecimento\xa0'},
#                                 {'Descripcion linea Adquisicion': 'Município '
#                                                                   'Instituição'},
#                                 {'Descripcion Proveedor': 'CNPJ Fornecedor'},
#                                 {'Unidad Medida': 'Competência CMED'},
#                                 {'Nombre Proveedor': 'Fornecedor'},
#                                 {'Estado Oferta': 'Tipo Compra'},
#                                 {'Cantidad Ofertada': '\xa0Média '
#                                                       'Ponderada\xa0'},
#                                 {'Moneda de la Oferta': 'Modalidade da Compra'},
#                                 {'Monto Unitario Oferta': 'Preço Unitário'},
#                                 {'Valor Total Ofertado': '\xa0Data Compra\xa0'},
#                                 {'Cantidad Adjudicada': 'Modalidade da Compra'},
#                                 {'Monto Linea Adjudica': 'Modalidade da '
#                                                          'Compra'},
#                                 {'Fecha Envio Oferta': 'Fornecedor'},
#                                 {'Oferta seleccionada': 'Descrição\xa0CATMAT'},
#                                 {'CHL-USD': 'CMED - Preço Regulado'},
#                                 {'Monto Unitario Oferta USD': 'Preço Unitário'},
#                                 {'Monto Linea Adjudica USD': 'Modalidade da '
#                                                              'Compra'},
#                                 {'Valor Total Ofertado USD': 'Qtd Itens '
#                                                              'Comprados'},
#                                 {'Tipo de Institucion': 'Nome Instituição'}]},
#  {'PERCardio Feb22-DOMComprasCardio': [{'RazonSocial': 'Registro Anvisa'},
#                                        {'Código Entidad': 'Código BR'},
#                                        {'Entidad': 'Competência CMED'},
#                                        {'Código Disa/Diresa': 'Código BR'},
#                                        {'Establecimiento': '\xa0Unidade de '
#                                                            'Fornecimento\xa0'},
#                                        {'Código Unidad Ejecutora': 'Código BR'},
#                                        {'Punto de Entrega': '\xa0Unidade de '
#                                                             'Fornecimento\xa0'},
#                                        {'Identificación Proceso': '\xa0Data '
#                                                                   'Inserção'},
#                                        {'Código Producto': 'Código BR'},
#                                        {'Producto': 'Preço Unitário'},
#                                        {'Cantidad': 'Fabricante'},
#                                        {'Precio Unitario Referencial': 'Preço '
#                                                                        'Unitário'},
#                                        {'Monto Total Referencial': '\xa0'
#                                                                    'Unidade de '
#                                                                    'Fornecimento\xa0'},
#                                        {'Precio Unitario Ofertado': 'Preço '
#                                                                     'Unitário'},
#                                        {'Monto Total Ofertado': 'Qtd Itens '
#                                                                 'Comprados'},
#                                        {'Pais': '\xa0Data Inserção'}]}]

# %%
import os
import csv
res_fp = 'schema-compare'
for merge_mapping_dict in merge_mapping_res:
    for files_name,value_pair in merge_mapping_dict.items():
        fname = os.path.join(res_fp, f'{files_name}.csv')
        with open(fname, 'w', newline='') as csvfile:
            files_name_sp = files_name.split('-')
            assert len(files_name_sp) == 2
            fieldnames = [files_name_sp[0], files_name_sp[1]]
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            writer.writeheader()
            for row in value_pair:
                for v1, v2 in row.items():
                    writer.writerow({fieldnames[0]: v1, fieldnames[1]: v2})
#         file = open(fname, 'wt')
#         print(fname)
#         for item in value_pair:
#             for v1, v2 in item.items():
#                 print(f'{v1},{v2}')
#                 file.write(v1+','+v2+'\n')
#         file.close()
